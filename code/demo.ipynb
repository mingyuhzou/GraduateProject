# %%
import polars as pl

# %%
data=pl.read_parquet('/home/ming/GraduateProject/Data/MINDlarge_dev/behaviors_1.parquet')

# %%
data['user_id'].count()
# Out:
# 376471

# %%
data['user_id'].unique().count()
# Out:
# 255990
