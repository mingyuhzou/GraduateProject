# %%
import polars as pl
import os

# %%
train_path='/home/ming/GraduateProject/Data/MINDsmall_train'
valid_path='/home/ming/GraduateProject/Data/MINDsmall_dev'
paths=[train_path,valid_path]

# %%
train=pl.read_parquet(os.path.join(train_path,'news.parquet'))
valid=pl.read_parquet(os.path.join(valid_path,'news.parquet'))

# %%
train.unique()
# Out:
# shape: (51_282, 8)
# ┌─────────┬──────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ news_id ┆ category ┆ subcategor ┆ title      ┆ abstract   ┆ url        ┆ title_enti ┆ abstract_e │
# │ ---     ┆ ---      ┆ y          ┆ ---        ┆ ---        ┆ ---        ┆ ties       ┆ ntities    │
# │ str     ┆ str      ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---        ┆ ---        │
# │         ┆          ┆ str        ┆            ┆            ┆            ┆ list[struc ┆ list[struc │
# │         ┆          ┆            ┆            ┆            ┆            ┆ t[6]]      ┆ t[6]]      │
# ╞═════════╪══════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ N26443  ┆ sports   ┆ basketball ┆ Agent:     ┆ When it    ┆ https://as ┆ [{"Pasco   ┆ [{"Pasco   │
# │         ┆          ┆ _nba       ┆ Sinkhole   ┆ comes to   ┆ sets.msn.c ┆ County,    ┆ County,    │
# ...

# %%
valid.unique()
# Out:
# shape: (42_416, 8)
# ┌─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ news_id ┆ category   ┆ subcategor ┆ title      ┆ abstract   ┆ url        ┆ title_ent ┆ abstract_ │
# │ ---     ┆ ---        ┆ y          ┆ ---        ┆ ---        ┆ ---        ┆ ities     ┆ entities  │
# │ str     ┆ str        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---       ┆ ---       │
# │         ┆            ┆ str        ┆            ┆            ┆            ┆ list[stru ┆ list[stru │
# │         ┆            ┆            ┆            ┆            ┆            ┆ ct[6]]    ┆ ct[6]]    │
# ╞═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ N58447  ┆ news       ┆ newsus     ┆ Kincade    ┆ Following  ┆ https://as ┆ [{"Pacifi ┆ [{"Pacifi │
# │         ┆            ┆            ┆ fire:      ┆ three      ┆ sets.msn.c ┆ c Gas and ┆ c Gas and │
# ...

# %%
data=pl.concat([train,valid],how='vertical').unique(subset=['news_id'])
data.describe()
# Out:
# shape: (9, 9)
# ┌────────────┬─────────┬──────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic  ┆ news_id ┆ category ┆ subcategor ┆ … ┆ abstract  ┆ url       ┆ title_ent ┆ abstract_ │
# │ ---        ┆ ---     ┆ ---      ┆ y          ┆   ┆ ---       ┆ ---       ┆ ities     ┆ entities  │
# │ str        ┆ str     ┆ str      ┆ ---        ┆   ┆ str       ┆ str       ┆ ---       ┆ ---       │
# │            ┆         ┆          ┆ str        ┆   ┆           ┆           ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪══════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count      ┆ 65238   ┆ 65238    ┆ 65238      ┆ … ┆ 65238     ┆ 65238     ┆ 65238.0   ┆ 65238.0   │
# │ null_count ┆ 0       ┆ 0        ┆ 0          ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0       │
# │ mean       ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# ...

# %%
data.write_parquet('/home/ming/GraduateProject/Data/small_news.parquet')
