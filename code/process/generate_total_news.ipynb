# %%
import polars as pl
import os

# %%
train_path='/home/ming/GraduateProject/Data/MINDlarge_train'
valid_path='/home/ming/GraduateProject/Data/MINDlarge_dev'
paths=[train_path,valid_path]

# %%
train=pl.read_parquet(os.path.join(train_path,'news.parquet'))
valid=pl.read_parquet(os.path.join(valid_path,'news.parquet'))

# %%
train.unique()
# Out:
# shape: (101_527, 8)
# ┌─────────┬──────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ news_id ┆ category ┆ subcategor ┆ title      ┆ abstract   ┆ url        ┆ title_enti ┆ abstract_e │
# │ ---     ┆ ---      ┆ y          ┆ ---        ┆ ---        ┆ ---        ┆ ties       ┆ ntities    │
# │ str     ┆ str      ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---        ┆ ---        │
# │         ┆          ┆ str        ┆            ┆            ┆            ┆ list[struc ┆ list[struc │
# │         ┆          ┆            ┆            ┆            ┆            ┆ t[6]]      ┆ t[6]]      │
# ╞═════════╪══════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ N35515  ┆ sports   ┆ football_n ┆ Seahawks   ┆ Seattle    ┆ https://as ┆ [{"Seattle ┆ [{"Seattle │
# │         ┆          ┆ fl         ┆ receiver   ┆ Seahawks   ┆ sets.msn.c ┆ Seahawks", ┆ Seahawks", │
# │         ┆          ┆            ┆ Jaron      ┆ wide       ┆ om/labs/mi ┆ "O","Q221… ┆ "O","Q221… │
# │         ┆          ┆            ┆ Brown …    ┆ receiver…  ┆ …          ┆            ┆            │
# │ N12952  ┆ sports   ┆ basketball ┆ Porzingis  ┆ The        ┆ https://as ┆ [{"Kristap ┆ [{"Kristap │
# │         ┆          ┆ _nba       ┆ has 1      ┆ divorce    ┆ sets.msn.c ┆ s Porziņģi ┆ s Porziņģi │
# │         ┆          ┆            ┆ regret     ┆ from the   ┆ om/labs/mi ┆ s","P","Q1 ┆ s","P","Q1 │
# │         ┆          ┆            ┆ after m…   ┆ Knicks "w… ┆ …          ┆ …          ┆ …          │
# │ N87185  ┆ news     ┆ newsbusine ┆ 'Disaster  ┆ Insurance  ┆ https://as ┆ []         ┆ [{"Dayton  │
# │         ┆          ┆ ss         ┆ after the  ┆ companies  ┆ sets.msn.c ┆            ┆ Daily News │
# │         ┆          ┆            ┆ disaster:' ┆ have       ┆ om/labs/mi ┆            ┆ ","M","Q52 │
# │         ┆          ┆            ┆ …          ┆ becom…     ┆ …          ┆            ┆ …          │
# │ N65181  ┆ video    ┆ viral      ┆ Two-Year-O ┆ While      ┆ https://as ┆ []         ┆ [{"Storyfu │
# │         ┆          ┆            ┆ ld Does    ┆ anyone who ┆ sets.msn.c ┆            ┆ l","N","Q1 │
# │         ┆          ┆            ┆ Not        ┆ has seen   ┆ om/labs/mi ┆            ┆ 9716893",1 │
# │         ┆          ┆            ┆ Approve …  ┆ the …      ┆ …          ┆            ┆ …          │
# │ N81115  ┆ finance  ┆ financenew ┆ Chicago    ┆ The latest ┆ https://as ┆ [{"Chicago ┆ [{"Chicago │
# │         ┆          ┆ s          ┆ Teachers'  ┆ Chicago    ┆ sets.msn.c ┆ ","G","Q12 ┆ Public Sch │
# │         ┆          ┆            ┆ Strike Is  ┆ Public     ┆ om/labs/mi ┆ 97",0.994, ┆ ools","G"… │
# │         ┆          ┆            ┆ 7t…        ┆ Scho…      ┆ …          ┆ …          ┆            │
# │ …       ┆ …        ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ N120207 ┆ news     ┆ newsus     ┆ Infant     ┆ An infant  ┆ https://as ┆ [{"Walnut, ┆ [{"Walnut, │
# │         ┆          ┆            ┆ death inve ┆ was        ┆ sets.msn.c ┆ California ┆ California │
# │         ┆          ┆            ┆ stigated   ┆ pronounced ┆ om/labs/mi ┆ ","G","Q8… ┆ ","G","Q8… │
# │         ┆          ┆            ┆ in W…      ┆ dead …     ┆ …          ┆            ┆            │
# │ N45272  ┆ finance  ┆ finance-re ┆ A          ┆ A nearly   ┆ https://as ┆ [{"Scottsd ┆ [{"Scottsd │
# │         ┆          ┆ al-estate  ┆ Scottsdale ┆ 8,000 squa ┆ sets.msn.c ┆ ale, Arizo ┆ ale, Arizo │
# │         ┆          ┆            ┆ mansion    ┆ re-foot    ┆ om/labs/mi ┆ na","G","Q ┆ na","G","Q │
# │         ┆          ┆            ┆ with a ro… ┆ man…       ┆ …          ┆ …          ┆ …          │
# │ N60031  ┆ news     ┆ newsus     ┆ Stringer:  ┆ City compt ┆ https://as ┆ [{"Domesti ┆ [{"Domesti │
# │         ┆          ┆            ┆ Domestic   ┆ roller     ┆ sets.msn.c ┆ c violence ┆ c violence │
# │         ┆          ┆            ┆ Violence   ┆ Scott      ┆ om/labs/mi ┆ ","C","Q15 ┆ ","C","Q15 │
# │         ┆          ┆            ┆ Dr…        ┆ Stringe…   ┆ …          ┆ …          ┆ …          │
# │ N32673  ┆ weather  ┆ weathertop ┆ Here comes ┆ Like it or ┆ https://as ┆ [{"Northea ┆ [{"Northea │
# │         ┆          ┆ stories    ┆ the snow:  ┆ not,       ┆ sets.msn.c ┆ st Ohio"," ┆ st Ohio"," │
# │         ┆          ┆            ┆ Winter St… ┆ winter     ┆ om/labs/mi ┆ G","Q70579 ┆ G","Q70579 │
# │         ┆          ┆            ┆            ┆ weather…   ┆ …          ┆ …          ┆ …          │
# │ N123863 ┆ news     ┆ newsworld  ┆ New Delhi  ┆ An expert  ┆ https://as ┆ [{"New Del ┆ []         │
# │         ┆          ┆            ┆ schools    ┆ panel in   ┆ sets.msn.c ┆ hi","G","Q ┆            │
# │         ┆          ┆            ┆ shut       ┆ India's    ┆ om/labs/mi ┆ 987",1.0,[ ┆            │
# │         ┆          ┆            ┆ because…   ┆ cap…       ┆ …          ┆ …          ┆            │
# └─────────┴──────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
valid.unique()
# Out:
# shape: (72_023, 8)
# ┌─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ news_id ┆ category   ┆ subcategor ┆ title      ┆ abstract   ┆ url        ┆ title_ent ┆ abstract_ │
# │ ---     ┆ ---        ┆ y          ┆ ---        ┆ ---        ┆ ---        ┆ ities     ┆ entities  │
# │ str     ┆ str        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---       ┆ ---       │
# │         ┆            ┆ str        ┆            ┆            ┆            ┆ list[stru ┆ list[stru │
# │         ┆            ┆            ┆            ┆            ┆            ┆ ct[6]]    ┆ ct[6]]    │
# ╞═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ N88237  ┆ finance    ┆ finance-re ┆ Real       ┆ Looking    ┆ https://as ┆ [{"Nashvi ┆ [{"Gallat │
# │         ┆            ┆ al-estate  ┆ estate:    ┆ for a home ┆ sets.msn.c ┆ lle, Tenn ┆ in, Tenne │
# │         ┆            ┆            ┆ What       ┆ in the     ┆ om/labs/mi ┆ essee","G ┆ ssee","G" │
# │         ┆            ┆            ┆ $299,900   ┆ Nash…      ┆ …          ┆ ","…      ┆ ,"Q…      │
# │         ┆            ┆            ┆ wil…       ┆            ┆            ┆           ┆           │
# │ N29736  ┆ sports     ┆ baseball_m ┆ Ex-Nats    ┆ The        ┆ https://as ┆ [{"Matt   ┆ [{"Washin │
# │         ┆            ┆ lb         ┆ manager    ┆ Athletics  ┆ sets.msn.c ┆ Williams  ┆ gton Nati │
# │         ┆            ┆            ┆ Matt       ┆ third base ┆ om/labs/mi ┆ (third    ┆ onals","O │
# │         ┆            ┆            ┆ Williams … ┆ coach…     ┆ …          ┆ basema…   ┆ ","…      │
# │ N67789  ┆ foodanddri ┆ newstrends ┆ Cleveland  ┆ CLEVELAND, ┆ https://as ┆ []        ┆ [{"Clevel │
# │         ┆ nk         ┆            ┆ Pizza Week ┆ Ohio -     ┆ sets.msn.c ┆           ┆ and","G", │
# │         ┆            ┆            ┆ kicks off… ┆ More than  ┆ om/labs/mi ┆           ┆ "Q37320", │
# │         ┆            ┆            ┆            ┆ tw…        ┆ …          ┆           ┆ 1.0…      │
# │ N74596  ┆ news       ┆ newsus     ┆ Protest    ┆ Demonstrat ┆ https://as ┆ [{"Minnea ┆ [{"Richfi │
# │         ┆            ┆            ┆ Over       ┆ ors on     ┆ sets.msn.c ┆ polis","G ┆ eld, Minn │
# │         ┆            ┆            ┆ Unreleased ┆ Friday     ┆ om/labs/mi ┆ ","Q36091 ┆ esota","G │
# │         ┆            ┆            ┆ Brian …    ┆ will d…    ┆ …          ┆ ",1…      ┆ ","…      │
# │ N126969 ┆ sports     ┆ baseball_m ┆ Former     ┆ Former     ┆ https://as ┆ [{"Josh   ┆ [{"Josh   │
# │         ┆            ┆ lb         ┆ Texas      ┆ Texas      ┆ sets.msn.c ┆ Hamilton" ┆ Hamilton" │
# │         ┆            ┆            ┆ Ranger     ┆ Ranger     ┆ om/labs/mi ┆ ,"P","Q71 ┆ ,"P","Q71 │
# │         ┆            ┆            ┆ Josh       ┆ Josh       ┆ …          ┆ 6346…     ┆ 6346…     │
# │         ┆            ┆            ┆ Hamil…     ┆ Hamil…     ┆            ┆           ┆           │
# │ …       ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …         ┆ …         │
# │ N118566 ┆ sports     ┆ football_n ┆ NFL        ┆ NFL        ┆ https://as ┆ [{"Joe    ┆ [{"Joe    │
# │         ┆            ┆ fl_videos  ┆ Network    ┆ Network    ┆ sets.msn.c ┆ Flacco"," ┆ Flacco"," │
# │         ┆            ┆            ┆ Insider    ┆ Insider    ┆ om/labs/mi ┆ P","Q7954 ┆ P","Q7954 │
# │         ┆            ┆            ┆ Ian        ┆ Ian        ┆ …          ┆ 06",1…    ┆ 06",1…    │
# │         ┆            ┆            ┆ Rapopo…    ┆ Rapopo…    ┆            ┆           ┆           │
# │ N54461  ┆ sports     ┆ football_n ┆ Antonio    ┆ Antonio    ┆ https://as ┆ [{"Antoni ┆ [{"Antoni │
# │         ┆            ┆ fl         ┆ Brown says ┆ Brown has  ┆ sets.msn.c ┆ o Brown", ┆ o Brown", │
# │         ┆            ┆            ┆ Brady over ┆ been       ┆ om/labs/mi ┆ "P","Q477 ┆ "P","Q477 │
# │         ┆            ┆            ┆ …          ┆ relativ…   ┆ …          ┆ 647…      ┆ 647…      │
# │ N69547  ┆ news       ┆ newsscienc ┆ You'll     ┆ Austrian   ┆ https://as ┆ []        ┆ [{"Kickst │
# │         ┆            ┆ eandtechno ┆ soon be    ┆ start-up   ┆ sets.msn.c ┆           ┆ arter","O │
# │         ┆            ┆ logy       ┆ able to    ┆ Phonocut   ┆ om/labs/mi ┆           ┆ ","Q34755 │
# │         ┆            ┆            ┆ cut you…   ┆ has…       ┆ …          ┆           ┆ ",1…      │
# │ N1903   ┆ news       ┆ newsus     ┆ First      ┆ There are  ┆ https://as ┆ [{"Baltim ┆ [{"Baltim │
# │         ┆            ┆            ┆ weekend of ┆ a lot of   ┆ sets.msn.c ┆ ore","G", ┆ ore","G", │
# │         ┆            ┆            ┆ November   ┆ events     ┆ om/labs/mi ┆ "Q5092",0 ┆ "Q5092",0 │
# │         ┆            ┆            ┆ brin…      ┆ happ…      ┆ …          ┆ .99…      ┆ .99…      │
# │ N45361  ┆ news       ┆ newscrime  ┆ Man        ┆ The man    ┆ https://as ┆ []        ┆ []        │
# │         ┆            ┆            ┆ accused of ┆ threw      ┆ sets.msn.c ┆           ┆           │
# │         ┆            ┆            ┆ barricadin ┆ items at   ┆ om/labs/mi ┆           ┆           │
# │         ┆            ┆            ┆ g him…     ┆ officer…   ┆ …          ┆           ┆           │
# └─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┘

# %%
data=pl.concat([train,valid],how='vertical').unique(subset=['news_id'])
data.describe()
# Out:
# shape: (9, 9)
# ┌────────────┬─────────┬──────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic  ┆ news_id ┆ category ┆ subcategor ┆ … ┆ abstract  ┆ url       ┆ title_ent ┆ abstract_ │
# │ ---        ┆ ---     ┆ ---      ┆ y          ┆   ┆ ---       ┆ ---       ┆ ities     ┆ entities  │
# │ str        ┆ str     ┆ str      ┆ ---        ┆   ┆ str       ┆ str       ┆ ---       ┆ ---       │
# │            ┆         ┆          ┆ str        ┆   ┆           ┆           ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪══════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count      ┆ 104151  ┆ 104151   ┆ 104151     ┆ … ┆ 104151    ┆ 104151    ┆ 104151.0  ┆ 104151.0  │
# │ null_count ┆ 0       ┆ 0        ┆ 0          ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0       │
# │ mean       ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ std        ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ min        ┆ N1      ┆ autos    ┆ ads-lating ┆ … ┆           ┆ https://a ┆ null      ┆ null      │
# │            ┆         ┆          ┆ rammys     ┆   ┆           ┆ ssets.msn ┆           ┆           │
# │            ┆         ┆          ┆            ┆   ┆           ┆ .com/labs ┆           ┆           │
# │            ┆         ┆          ┆            ┆   ┆           ┆ /mi…      ┆           ┆           │
# │ 25%        ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 50%        ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 75%        ┆ null    ┆ null     ┆ null       ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ max        ┆ N99999  ┆ weather  ┆ yearinoffb ┆ … ┆ ﻿UPDATE @  ┆ https://a ┆ null      ┆ null      │
# │            ┆         ┆          ┆ eatgoodnew ┆   ┆ 9:40      ┆ ssets.msn ┆           ┆           │
# │            ┆         ┆          ┆ s          ┆   ┆ a.m.:     ┆ .com/labs ┆           ┆           │
# │            ┆         ┆          ┆            ┆   ┆           ┆ /mi…      ┆           ┆           │
# └────────────┴─────────┴──────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data.write_parquet('/home/ming/GraduateProject/Data/news.parquet')
